# %%
file = open('small.txt').readlines()
file = [i.replace('\n', '') for i in file]
file = [list(i) for i in file]

# %%
row_len = len(file)-1
col_len = len(file[0])-1

# %%
print(col_len)
# Out:
# 9

# %%
import itertools
positions = list(itertools.product([-1,0,1],repeat = 2))
positions.pop(4)
# Out:
# (0, 0)

# %%
def print_table(listx):
    """returns a grid of a list of lists of numbers

    list of list -> grid"""
    for lists in listx:
        for i in lists:
            print(i,end='')
        print()

# %%
old_file = []
def check_mmzz(x,y):
    return x > row_len or y > col_len or x < 0 or y < 0
positions = list(itertools.product([-1,0,1],repeat = 2))
positions.pop(4)

counter = 0
while old_file != file:

    counter += 1
    old_file = [x.copy() for x in file]
    for row in range(row_len+1):
        for col in range(col_len+1):
            seat = old_file[row][col]
            if seat == '.':
                pass
            elif seat == '#':
                li = []
                for x, y in positions:
                    if not check_mmzz(row+x,col+y):
                        li.append(old_file[row+x][col+y] == '#')
                if sum(li)>=4:
                    file[row][col] = 'L'
            elif seat == 'L':
                li = []
                for x, y in positions:
                    if not check_mmzz(row+x,col+y):
                        li.append(old_file[row+x][col+y] == '#')
                if not sum(li):
                    file[row][col] = '#'

# %%
fuck = []
for i in range(row_len+1):
    for j in range(col_len+1):
        fuck.append(file[i][j] == '#')

# %%
print_table(file)
# Out:
# #L#L#L.L#L#L#L#L#.#L##L#.#L#L#L#L#.#L#L..#LL#.#L##L#.#LL#.#L#L#L#L#L#L#L#L#L##L#L#L#L#L#L#L#L#L#
# LLLLLL#LLLL.LLLLL.LLLLLL.LLLLLLLLL.L.LL#.LLLL.LLLLLL.LLLL.LLLLLLLLL.LLLLLLLL.LLLLL.LLLLLLLLLLLLL
# #L#L#L.L#L#.#L#L#.#L##L#.#L#L#L#L#.#L#LL.#L.#.#L#L##.#L##.#L#L#L#L#.#L#L#L.#L##L#L#L#.#L#L#L#L##
# LLLLLL.LLLL.#LLLL.LLLLLL.LLLLLLLLL.LLLLL.LLLL..LLLLLLLLLL.LLLLLLLLLLLLLLLL.LLLLLLLLLLLLLLL.LL.LL
# #L#L##.#L##.LL#L#.#L##L#.#L#####L#.#L##L##L#L##L##L#.##L#.#L#L#L#L#L#L##L#L#L###L#.#L#L#L#L#L#L#
# ..L.L....L.L#.L.L..L..L..LL.....LL.L..L...LL....L..L.LL...LLLL.LL.L.LL....L.L.L.LLL#.L....L.....
# #L#L#L##L##LLL#L#L#L##L#.#L#L#L#L#.#L#L#.###...#L#L#.#L#L#L#L#L#L#L.L#L#L#L#L#L#L#.#L#L#L#L#L#L#
# LLLLLL.LL##.#LLLL.LLLLLL.LLLLLLLLL..LLLLLL.LL.LLL#LL.LLLL.LLLLLLLLL#LLLLLLLLLLLLLL.LLLLLLL.LLLLL
# #L#LL#.#LLL.#L#L#.#L##L#.#L#L#L#L#.#L#L#.##L#.#LLLL#.#L#L#L#L#L#L#..L#L#L######L#L#L#.L#L#.#L#L#
# .LLLLL.LL#L#LLLLL..LLL.L.LLLLLLLLL.LLLLL.LLLLL.L##.L.LLLLLLLLLLLLLL.LLLLL#.LLLLLLLLLLLLLLLLLLLLL
# #L#L#L.L#L#L#L#L..##L#L#L#L#L#L#L#.#L#L#.#LLL.L#L#L#.#L##.#L#L#L#.#.#L#L#L.#L#L#L#L#L#L#LL.LL#L#
# LLLLLL.LLLLLLLLL#LLLLLLL.LLLLLLLLL.LL.LLLLLLL#LLLLLL.LLLL.LLLLLLLLL..LLLLLLLLLLLLL.LLLLLL#.#LLLL
# #L#L#L#L#L#.#L#L#.L#L#L#.#L#L#L#L#L#.#L#L#L#L.L#L#L#.#L#L#L#L#L#L#L##L#L#L.#L#L#L#.#L#L#LL.#L#L#
# LLLLLL.LLLL.LLLLLLLLLLLLLLLLLLLLLL.LLLLL.LLLLLLLLLLL.LLL..L.LLLLLL..LLLLLL.LLLLLLL.LLLLLL#LLLLLL
# #.#L#L#L#L#.#L#L#L#L#L#L#LL#L#L#L#L#L#L#.#L.#.#LL#L#.#LL#.#L#L#L#L#.#L##L#.#L#L#L#.#L#L#L#.#L#L#

# %%
sum(fuck)
# Out:
# 2424

# %%
def check_kind(kind):
    if kind == '.':
        return (True,True)
    elif kind == 'L':
        return (True,False)
    elif kind == '#':
        return (False,False)

# %%
def check_view(file, x, y):
    print('------')
    print(check_diag(file, x, y))
    print(check_vert(file, x, y))
    print(check_hor(file, x, y))
    print(check_hor(file, x, y) + check_vert(file, x, y) + check_diag(file, x, y))
    print('------')
    return (check_diag(file, x, y) + check_vert(file, x, y) + check_hor(file, x, y)) >= 5
def check_diag(file, x, y):
    filled = 0
    for leftdiag in range(min(row, col)-1,0-1,-1):
        empty, continued = check_kind(file[row - leftdiag - 1][col - leftdiag - 1])
        if not empty:
            filled += 1
        if not continued:
            break
    for rightdiag in range(min(row,col_len-col)-1,0-1,-1):
        empty, continued = check_kind(file[row - rightdiag - 1][col + rightdiag + 1])
        if not empty:
            filled += 1
        if not continued:
            break
    for leftdown in range(min(col,row_len-row)-1,0-1,-1):
        empty, continued = check_kind(file[row+leftdown+1][col - leftdown-1])
        if not empty:
            filled += 1
        if not continued:
            break
    for rightdown in range(min(row_len-row, col_len-col)-1,0-1,-1):
        empty, continued = check_kind(file[row+1+rightdown][col + 1 +rightdown])
        if not empty:
            filled += 1
        if not continued:
            break
    return filled
        
def check_vert(file, row, col):
    filled = 0
    for above in range(row-1,-1,-1):
        empty, continued = check_kind(file[above][col])
        if not empty:
            filled += 1
        if not continued:
            break
    for below in range(row+1,row_len+1,1):
        empty, continued= check_kind(file[below][col])
        if not empty:
            print
            filled += 1
        if not continued:
            break
    return filled
def check_hor(file, row, col):
    filled = 0
    for left in range(col-1,-1,-1):
        empty, continued = check_kind(file[row][left])
        if not empty:
            filled += 1
        if not continued:
            break
    for right in range(col+1,col_len+1,1):
        empty, continued = check_kind(file[row][right])
        if not empty:
            filled += 1
        if not continued:
            break
    return filled

# %%
file = open('small.txt').readlines()
file = [i.replace('\n', '') for i in file]
file = [list(i) for i in file]

# %%
old_file = []
def check_mmzz(x,y):
    return x > row_len or y > col_len or x < 0 or y < 0

counter = 0
while old_file != file:

    counter += 1
    old_file = [x.copy() for x in file]
        
   
    print_table(old_file)
    print('hello')
    
    for row in range(row_len+1):
        for col in range(col_len+1):
            seat = old_file[row][col]
            if seat == '.':
                pass
            elif seat == '#':
                print('row',row,'col',col)
                if check_view(old_file,row,col):
                    file[row][col] = 'L'
            elif seat == 'L':
                li = []
                for x, y in positions:
                    if not check_mmzz(row+x,col+y):
                        li.append(old_file[row+x][col+y] == '#')
                if not sum(li):
                    file[row][col] = '#'
        print_table(file)
# Out:
# L.LL.LL.LL
# LLLLLLL.LL
# L.L.L..L..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLLL
# L.LLLLLL.L
# L.LLLLL.LL
# hello
# #.##.##.##
# LLLLLLL.LL
# L.L.L..L..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLLL
# L.LLLLLL.L
# L.LLLLL.LL
# #.##.##.##
# #######.##
# L.L.L..L..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLLL
# L.LLLLLL.L
# L.LLLLL.LL
# #.##.##.##
# #######.##
# #.#.#..#..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLLL
# L.LLLLLL.L
# L.LLLLL.LL
# #.##.##.##
# #######.##
# #.#.#..#..
# ####.##.##
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLLL
# L.LLLLLL.L
# L.LLLLL.LL
# #.##.##.##
# #######.##
# #.#.#..#..
# ####.##.##
# #.##.##.##
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLLL
# L.LLLLLL.L
# L.LLLLL.LL
# #.##.##.##
# #######.##
# #.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..L.L.....
# LLLLLLLLLL
# L.LLLLLL.L
# L.LLLLL.LL
# #.##.##.##
# #######.##
# #.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# LLLLLLLLLL
# L.LLLLLL.L
# L.LLLLL.LL
# #.##.##.##
# #######.##
# #.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# ##########
# L.LLLLLL.L
# L.LLLLL.LL
# #.##.##.##
# #######.##
# #.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# ##########
# #.######.#
# L.LLLLL.LL
# #.##.##.##
# #######.##
# #.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# ##########
# #.######.#
# #.#####.##
# #.##.##.##
# #######.##
# #.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# ##########
# #.######.#
# #.#####.##
# hello
# row 0 col 0
# ------
# 1
# 1
# 1
# 3
# ------
# row 0 col 2
# ------
# 2
# 1
# 2
# 5
# ------
# row 0 col 3
# ------
# 2
# 1
# 2
# 5
# ------
# row 0 col 5
# ------
# 2
# 1
# 2
# 5
# ------
# row 0 col 6
# ------
# 2
# 1
# 2
# 5
# ------
# row 0 col 8
# ------
# 2
# 1
# 2
# 5
# ------
# row 0 col 9
# ------
# 1
# 1
# 1
# 3
# ------
# #.LL.LL.L#
# #######.##
# #.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# 
# #LLLLLL.LL
# L.L.L..L..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..#.#.....
# ##########
# #.######.#
# #.#####.##
# row 6 col 2
# ------
# 4
# 2
# 1
# 7
# ------
# row 6 col 4
# ------
# 4
# 2
# 1
# 7
# ------
# #.LL.LL.L#
# #LLLLLL.LL
# L.L.L..L..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# ##########
# #.######.#
# #.#####.##
# row 7 col 0
# ------
# 2
# 2
# 1
# 5
# ------
# row 7 col 1
# ------
# 3
# 1
# 2
# 6
# ------
# row 7 col 2
# ------
# 4
# 2
# 2
# 8
# ------
# row 7 col 3
# ------
# 4
# 2
# 2
# 8
# ------
# row 7 col 4
# ------
# 4
# 2
# 2
# 8
# ------
# row 7 col 5
# ------
# 4
# 2
# 2
# 8
# ------
# row 7 col 6
# ------
# 4
# 2
# 2
# 8
# ------
# row 7 col 7
# ------
# 4
# 2
# 2
# 8
# ------
# row 7 col 8
# ------
# 3
# 2
# 2
# 7
# ------
# row 7 col 9
# ------
# 1
# 2
# 1
# 4
# ------
# #.LL.LL.L#
# #LLLLLL.LL
# L.L.L..L..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.######.#
# #.#####.##
# row 8 col 0
# ------
# 1
# 2
# 1
# 4
# ------
# row 8 col 2
# ------
# 3
# 2
# 2
# 7
# ------
# row 8 col 3
# ------
# 4
# 2
# 2
# 8
# ------
# row 8 col 4
# ------
# 4
# 2
# 2
# 8
# ------
# row 8 col 5
# ------
# 4
# 2
# 2
# 8
# ------
# row 8 col 6
# ------
# 3
# 2
# 2
# 7
# ------
# row 8 col 7
# ------
# 4
# 1
# 2
# 7
# ------
# row 8 col 9
# ------
# 2
# 2
# 1
# 5
# ------
# #.LL.LL.L#
# #LLLLLL.LL
# L.L.L..L..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLLL.L
# #.#####.##
# row 9 col 0
# ------
# 1
# 1
# 1
# 3
# ------
# row 9 col 2
# ------
# 2
# 1
# 2
# 5
# ------
# row 9 col 3
# ------
# 2
# 1
# 2
# 5
# ------
# row 9 col 4
# ------
# 2
# 1
# 2
# 5
# ------
# row 9 col 5
# ------
# 2
# 1
# 2
# 5
# ------
# row 9 col 6
# ------
# 2
# 1
# 2
# 5
# ------
# row 9 col 8
# ------
# 2
# 1
# 2
# 5
# ------
# row 9 col 9
# ------
# 1
# 1
# 1
# 3
# ------
# #.LL.LL.L#
# #LLLLLL.LL
# L.L.L..L..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLLL.L
# #.LLLLL.L#
# #.LL.LL.L#
# #LLLLLL.LL
# L.L.L..L..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLLL.L
# #.LLLLL.L#
# hello
# row 0 col 0
# ------
# 1
# 1
# 0
# 2
# ------
# row 0 col 9
# ------
# 1
# 0
# 0
# 1
# ------
# #.##.##.L#
# #LLLLLL.LL
# L.L.L..L..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLLL.L
# #.LLLLL.L#
# row 1 col 0
# ------
# 0
# 1
# 0
# 1
# ------
# #.##.##.L#
# #L#####.LL
# L.L.L..L..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLLL.L
# #.LLLLL.L#
# #.##.##.L#
# #L#####.LL
# L.#.#..#..
# LLLL.LL.LL
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLLL.L
# #.LLLLL.L#
# #.##.##.L#
# #L#####.LL
# L.#.#..#..
# ####.##.##
# L.LL.LL.LL
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLLL.L
# #.LLLLL.L#
# #.##.##.L#
# #L#####.LL
# L.#.#..#..
# ####.##.##
# #.##.##.##
# L.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLLL.L
# #.LLLLL.L#
# #.##.##.L#
# #L#####.LL
# L.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..L.L.....
# LLLLLLLLL#
# #.LLLLLL.L
# #.LLLLL.L#
# #.##.##.L#
# #L#####.LL
# L.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# LLLLLLLLL#
# #.LLLLLL.L
# #.LLLLL.L#
# row 7 col 9
# ------
# 0
# 0
# 0
# 0
# ------
# #.##.##.L#
# #L#####.LL
# L.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# LL######L#
# #.LLLLLL.L
# #.LLLLL.L#
# row 8 col 0
# ------
# 0
# 1
# 0
# 1
# ------
# #.##.##.L#
# #L#####.LL
# L.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# LL######L#
# #.######.L
# #.LLLLL.L#
# row 9 col 0
# ------
# 1
# 1
# 0
# 2
# ------
# row 9 col 9
# ------
# 1
# 0
# 0
# 1
# ------
# #.##.##.L#
# #L#####.LL
# L.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# LL######L#
# #.######.L
# #.#####.L#
# #.##.##.L#
# #L#####.LL
# L.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# LL######L#
# #.######.L
# #.#####.L#
# hello
# row 0 col 0
# ------
# 1
# 1
# 1
# 3
# ------
# row 0 col 2
# ------
# 1
# 1
# 2
# 4
# ------
# row 0 col 3
# ------
# 2
# 1
# 2
# 5
# ------
# row 0 col 5
# ------
# 2
# 1
# 2
# 5
# ------
# row 0 col 6
# ------
# 2
# 1
# 1
# 4
# ------
# row 0 col 9
# ------
# 1
# 0
# 0
# 1
# ------
# #.#L.L#.L#
# #L#####.LL
# L.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# LL######L#
# #.######.L
# #.#####.L#
# row 1 col 0
# ------
# 0
# 1
# 0
# 1
# ------
# row 1 col 2
# ------
# 2
# 2
# 1
# 5
# ------
# row 1 col 3
# ------
# 3
# 2
# 2
# 7
# ------
# row 1 col 4
# ------
# 4
# 1
# 2
# 7
# ------
# row 1 col 5
# ------
# 3
# 2
# 2
# 7
# ------
# row 1 col 6
# ------
# 2
# 2
# 1
# 5
# ------
# #.#L.L#.L#
# #LLLLLL.LL
# L.#.#..#..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# LL######L#
# #.######.L
# #.#####.L#
# row 2 col 2
# ------
# 4
# 2
# 1
# 7
# ------
# row 2 col 4
# ------
# 4
# 2
# 2
# 8
# ------
# row 2 col 7
# ------
# 4
# 1
# 1
# 6
# ------
# #.#L.L#.L#
# #LLLLLL.LL
# L.L.L..L..
# ####.##.##
# #.##.##.##
# #.#####.##
# ..#.#.....
# LL######L#
# #.######.L
# #.#####.L#
# row 3 col 0
# ------
# 2
# 1
# 1
# 4
# ------
# row 3 col 1
# ------
# 3
# 0
# 2
# 5
# ------
# row 3 col 2
# ------
# 3
# 2
# 2
# 7
# ------
# row 3 col 3
# ------
# 4
# 2
# 2
# 8
# ------
# row 3 col 5
# ------
# 3
# 2
# 2
# 7
# ------
# row 3 col 6
# ------
# 4
# 2
# 2
# 8
# ------
# row 3 col 8
# ------
# 3
# 1
# 2
# 6
# ------
# row 3 col 9
# ------
# 2
# 1
# 1
# 4
# ------
# #.#L.L#.L#
# #LLLLLL.LL
# L.L.L..L..
# #LLL.LL.L#
# #.##.##.##
# #.#####.##
# ..#.#.....
# LL######L#
# #.######.L
# #.#####.L#
# row 4 col 0
# ------
# 2
# 2
# 1
# 5
# ------
# row 4 col 2
# ------
# 2
# 2
# 2
# 6
# ------
# row 4 col 3
# ------
# 2
# 2
# 2
# 6
# ------
# row 4 col 5
# ------
# 3
# 2
# 2
# 7
# ------
# row 4 col 6
# ------
# 3
# 2
# 2
# 7
# ------
# row 4 col 8
# ------
# 4
# 2
# 2
# 8
# ------
# row 4 col 9
# ------
# 2
# 2
# 1
# 5
# ------
# #.#L.L#.L#
# #LLLLLL.LL
# L.L.L..L..
# #LLL.LL.L#
# L.LL.LL.LL
# #.#####.##
# ..#.#.....
# LL######L#
# #.######.L
# #.#####.L#
# row 5 col 0
# ------
# 2
# 1
# 1
# 4
# ------
# row 5 col 2
# ------
# 3
# 2
# 2
# 7
# ------
# row 5 col 3
# ------
# 2
# 2
# 2
# 6
# ------
# row 5 col 4
# ------
# 3
# 2
# 2
# 7
# ------
# row 5 col 5
# ------
# 3
# 2
# 2
# 7
# ------
# row 5 col 6
# ------
# 3
# 2
# 2
# 7
# ------
# row 5 col 8
# ------
# 3
# 1
# 2
# 6
# ------
# row 5 col 9
# ------
# 2
# 2
# 1
# 5
# ------
# #.#L.L#.L#
# #LLLLLL.LL
# L.L.L..L..
# #LLL.LL.L#
# L.LL.LL.LL
# #.LLLLL.LL
# ..#.#.....
# LL######L#
# #.######.L
# #.#####.L#
# row 6 col 2
# ------
# 3
# 2
# 1
# 6
# ------
# row 6 col 4
# ------
# 2
# 2
# 1
# 5
# ------
# #.#L.L#.L#
# #LLLLLL.LL
# L.L.L..L..
# #LLL.LL.L#
# L.LL.LL.LL
# #.LLLLL.LL
# ..L.L.....
# LL######L#
# #.######.L
# #.#####.L#
# row 7 col 2
# ------
# 4
# 2
# 1
# 7
# ------
# row 7 col 3
# ------
# 3
# 2
# 2
# 7
# ------
# row 7 col 4
# ------
# 4
# 2
# 2
# 8
# ------
# row 7 col 5
# ------
# 3
# 2
# 2
# 7
# ------
# row 7 col 6
# ------
# 3
# 2
# 2
# 7
# ------
# row 7 col 7
# ------
# 4
# 2
# 1
# 7
# ------
# row 7 col 9
# ------
# 1
# 1
# 0
# 2
# ------
# #.#L.L#.L#
# #LLLLLL.LL
# L.L.L..L..
# #LLL.LL.L#
# L.LL.LL.LL
# #.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.######.L
# #.#####.L#
# row 8 col 0
# ------
# 0
# 1
# 1
# 2
# ------
# row 8 col 2
# ------
# 1
# 2
# 2
# 5
# ------
# row 8 col 3
# ------
# 4
# 2
# 2
# 8
# ------
# row 8 col 4
# ------
# 4
# 2
# 2
# 8
# ------
# row 8 col 5
# ------
# 4
# 2
# 2
# 8
# ------
# row 8 col 6
# ------
# 2
# 2
# 2
# 6
# ------
# row 8 col 7
# ------
# 2
# 1
# 1
# 4
# ------
# #.#L.L#.L#
# #LLLLLL.LL
# L.L.L..L..
# #LLL.LL.L#
# L.LL.LL.LL
# #.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLL#.L
# #.#####.L#
# row 9 col 0
# ------
# 1
# 1
# 1
# 3
# ------
# row 9 col 2
# ------
# 1
# 1
# 2
# 4
# ------
# row 9 col 3
# ------
# 1
# 1
# 2
# 4
# ------
# row 9 col 4
# ------
# 2
# 1
# 2
# 5
# ------
# row 9 col 5
# ------
# 2
# 1
# 2
# 5
# ------
# row 9 col 6
# ------
# 1
# 1
# 1
# 3
# ------
# row 9 col 9
# ------
# 1
# 0
# 0
# 1
# ------
# #.#L.L#.L#
# #LLLLLL.LL
# L.L.L..L..
# #LLL.LL.L#
# L.LL.LL.LL
# #.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLL#.L
# #.##LL#.L#
# #.#L.L#.L#
# #LLLLLL.LL
# L.L.L..L..
# #LLL.LL.L#
# L.LL.LL.LL
# #.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLL#.L
# #.##LL#.L#
# hello
# row 0 col 0
# ------
# 1
# 1
# 1
# 3
# ------
# row 0 col 2
# ------
# 1
# 0
# 1
# 2
# ------
# row 0 col 6
# ------
# 1
# 0
# 0
# 1
# ------
# row 0 col 9
# ------
# 1
# 0
# 0
# 1
# ------
# #.#L.L#.L#
# #LLLLLL.LL
# L.L.L..L..
# #LLL.LL.L#
# L.LL.LL.LL
# #.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLL#.L
# #.##LL#.L#
# row 1 col 0
# ------
# 0
# 1
# 0
# 1
# ------
# #.#L.L#.L#
# #LLL#LL.LL
# L.L.L..L..
# #LLL.LL.L#
# L.LL.LL.LL
# #.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLL#.L
# #.##LL#.L#
# #.#L.L#.L#
# #LLL#LL.LL
# L.#.#..#..
# #LLL.LL.L#
# L.LL.LL.LL
# #.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLL#.L
# #.##LL#.L#
# row 3 col 0
# ------
# 1
# 0
# 0
# 1
# ------
# row 3 col 9
# ------
# 2
# 0
# 0
# 2
# ------
# #.#L.L#.L#
# #LLL#LL.LL
# L.#.#..#..
# #L##.##.L#
# L.LL.LL.LL
# #.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLL#.L
# #.##LL#.L#
# #.#L.L#.L#
# #LLL#LL.LL
# L.#.#..#..
# #L##.##.L#
# L.##.##.LL
# #.LLLLL.LL
# ..L.L.....
# LLLLLLLLL#
# #.LLLLL#.L
# #.##LL#.L#
# row 5 col 0
# ------
# 0
# 0
# 0
# 0
# ------
# #.#L.L#.L#
# #LLL#LL.LL
# L.#.#..#..
# #L##.##.L#
# L.##.##.LL
# #.#####.##
# ..L.L.....
# LLLLLLLLL#
# #.LLLLL#.L
# #.##LL#.L#
# #.#L.L#.L#
# #LLL#LL.LL
# L.#.#..#..
# #L##.##.L#
# L.##.##.LL
# #.#####.##
# ..#.#.....
# LLLLLLLLL#
# #.LLLLL#.L
# #.##LL#.L#
# row 7 col 9
# ------
# 1
# 0
# 0
# 1
# ------
# #.#L.L#.L#
# #LLL#LL.LL
# L.#.#..#..
# #L##.##.L#
# L.##.##.LL
# #.#####.##
# ..#.#.....
# LL####LLL#
# #.LLLLL#.L
# #.##LL#.L#
# row 8 col 0
# ------
# 0
# 1
# 0
# 1
# ------
# row 8 col 7
# ------
# 2
# 0
# 0
# 2
# ------
# #.#L.L#.L#
# #LLL#LL.LL
# L.#.#..#..
# #L##.##.L#
# L.##.##.LL
# #.#####.##
# ..#.#.....
# LL####LLL#
# #.LLLLL#.L
# #.##LL#.L#
# row 9 col 0
# ------
# 1
# 1
# 1
# 3
# ------
# row 9 col 2
# ------
# 0
# 0
# 2
# 2
# ------
# row 9 col 3
# ------
# 1
# 0
# 1
# 2
# ------
# row 9 col 6
# ------
# 1
# 0
# 0
# 1
# ------
# row 9 col 9
# ------
# 1
# 0
# 0
# 1
# ------
# #.#L.L#.L#
# #LLL#LL.LL
# L.#.#..#..
# #L##.##.L#
# L.##.##.LL
# #.#####.##
# ..#.#.....
# LL####LLL#
# #.LLLLL#.L
# #.##LL#.L#
# #.#L.L#.L#
# #LLL#LL.LL
# L.#.#..#..
# #L##.##.L#
# L.##.##.LL
# #.#####.##
# ..#.#.....
# LL####LLL#
# #.LLLLL#.L
# #.##LL#.L#
# hello
# row 0 col 0
# ------
# 1
# 1
# 1
# 3
# ------
# row 0 col 2
# ------
# 1
# 0
# 1
# 2
# ------
# row 0 col 6
# ------
# 2
# 0
# 0
# 2
# ------
# row 0 col 9
# ------
# 1
# 0
# 0
# 1
# ------
# #.#L.L#.L#
# #LLL#LL.LL
# L.#.#..#..
# #L##.##.L#
# L.##.##.LL
# #.#####.##
# ..#.#.....
# LL####LLL#
# #.LLLLL#.L
# #.##LL#.L#
# row 1 col 0
# ------
# 0
# 1
# 0
# 1
# ------
# row 1 col 4
# ------
# 2
# 1
# 0
# 3
# ------
# #.#L.L#.L#
# #LLL#LL.LL
# L.#.#..#..
# #L##.##.L#
# L.##.##.LL
# #.#####.##
# ..#.#.....
# LL####LLL#
# #.LLLLL#.L
# #.##LL#.L#
# row 2 col 2
# ------
# 2
# 1
# 1
# 4
# ------
# row 2 col 4
# ------
# 4
# 2
# 2
# 8
# ------
# row 2 col 7
# ------
# 2
# 0
# 1
# 3
# ------
# #.#L.L#.L#
# #LLL#LL.LL
# L.#.L..#..
# #L##.##.L#
# L.##.##.LL
# #.#####.##
# ..#.#.....
# LL####LLL#
# #.LLLLL#.L
# #.##LL#.L#
# row 3 col 0
# ------
# 1
# 0
# 0
# 1
# ------
# row 3 col 2
# ------
# 2
# 2
# 1
# 5
# ------
# row 3 col 3
# ------
# 4
# 1
# 2
# 7
# ------
# row 3 col 5
# ------
# 3
# 1
# 2
# 6
# ------
# row 3 col 6
# ------
# 3
# 1
# 1
# 5
# ------
# row 3 col 9
# ------
# 2
# 0
# 0
# 2
# ------
# #.#L.L#.L#
# #LLL#LL.LL
# L.#.L..#..
# #LLL