# %%
file = open('input.txt')

# %%
file = file.read()

# %%
file = file.split('\n\n')

# %%
file.pop()
# Out:
# ''

# %%
peices = {i.split(':',1)[0] : i.split(':',1)[1] for i in file}

# %%
peices.values()
# Out:
# dict_values(['\n.#.##..#.#\n.#.......#\n.##...#.#.\n......#...\n#.#.......\n##.....#.#\n#..#...#..\n##........\n##....#...\n##..#.##.#', '\n#.#......#\n.#......##\n#.##..#..#\n...#..#.#.\n.#.#...#..\n#.........\n..#..#....\n#.#..#.##.\n#..##.....\n#...#.#.#.', '\n#...#..#..\n..##.....#\n..#...####\n#..#.#...#\n..#.#.#..#\n..####....\n#.#.###.#.\n......#...\n#.........\n#.#.##...#', '\n###.####.#\n#....###.#\n#.#......#\n..#....#..\n...#.....#\n.#..#...##\n#.#.....##\n#..#......\n.....#.#..\n...###.#.#', '\n###...#.#.\n.#...#..##\n.#.......#\n..........\n#.#.......\n....#.....\n######....\n#.....#...\n##.......#\n#.###..###', '\n.#..#..###\n###...#.##\n#.........\n....###..#\n#.#...#..#\n#....###..\n##..##...#\n#....##.##\n#.......#.\n###.##...#', '\n#####..##.\n##........\n......#.#.\n#..#...#.#\n.....##.#.\n.....#...#\n#.........\n#........#\n....#..#.#\n.#..#...#.', '\n##...#####\n#...#..#.#\n.##...#..#\n#...#.....\n#..#.#...#\n..#......#\n#.#.......\n....##..#.\n..#.#..##.\n####.#
# ...
